# %% [markdown]
# # Chapter IX-I Natural Energy System - PV System / 自然エネルギー利用設備 - 太陽光発電設備

# %% [markdown]
# ##  Energy Generated by PV System / 太陽光発電設備による発電量

# %% [markdown]
#  The hourly energy generated by PV system $E_{PV}$ is calculated by the equation below.

# %% [markdown]
# $$\large
# E_{PV} = \sum_{i}^{n} E_{p,i}
# $$

# %% [markdown]
# Where
# $E_{PV}$ is the hourly energy generated by PV system. / 1時間当たりの太陽光発電設備による発電量(kWh/h)
# $E_{p,i}$ is the hourly energy generated by PV array $i$. / 1時間当たりの太陽電池アレイ$i$の発電量(kWh/h)
# $n$ is the number of PV array. / 太陽電池アレイの数(Max4)

# %% [markdown]
# When $n$ exceeds 4, the energy generated by PV array is not evaluated. Furthermore, for a plurality of PV arrays in which the azimuth angle, the inclination angle, whether the semiconductor type is crystal system or not and the installation type are the same, it may be regarded as one PV array by totaling the system capacity of each PV array. In that case, round the third decimal place of the total system capacity of each PV array and use the value up to the second decimal place.

# %% [markdown]
# ## Energy Generated by PV Array  / 太陽電池アレイによる発電量

# %% [markdown]
# The hourly energy $E_{p,i}$ generated by PV array $i$  is calculated by the equation below.

# %% [markdown]
# $$\large
# E_{p,i} = P_{p,i} \times \frac{1}{\alpha_p} \times I_{S,i} \times K_{p,i} \times 10^{-3}
# $$

# %% [markdown]
# Where
# $P_{p,i}$ is the system capacity of PV array $i$. / 太陽電池アレイ$i$のシステム容量(kW)
# $\alpha_p$ is the solar irradiance in reference condition. / 基準状態の日射強度(kW/m<sup>2</sup>)
# $I_{S,i}$ is the solar irradiation per unit area of installation surface of PV array $i$. / 太陽電池アレイ$i$の設置面の単位面積当たりの日射量(W/m<sup>2</sup>)
# $K_{p,i}$ is the total design factor of PV array $i$. / 太陽電池アレイ$i$の総合設計係数

# %% [markdown]
# The solar irradiation per unit area of installation surface of PV array $i$ is determined by inclination angle $P_\beta$ and azimuth angle $P_\alpha$ and "annual insolation amount area classification". The calculation method is shown in Chapter 11, Section 2 Appendix A.

# %% [markdown]
# ## System Capacity of PV Array / 太陽電池アレイのシステム容量

# %% [markdown]
# The system capacity $P_{p,i}$ of the PV array $i$ is measured based on the measuring method of JIS C8951 "General rules for photovoltaic array" and if "STC PV array maximum power", displayed based on JIS C8952 "Indication of photovoltaic array performance" is described, it shall be equal to the value. When "STC PV array maximum power" is not described, it shall be the total of standard PV module output values per one sheet described in the manufacturer's specifications, technical materials etc. based on the following JIS.
# The system capacity $P_{p,i}$ of the PV array $i$ should be rounded to the third decimal place and the second decimal place.

# %% [markdown]
# <center>**Table 3. Compliant standard for standard PV module output**</center>
#
# <table>
# <thead>
# <tr>
# 	<th colspan="2" style="text-align: left;">Types of cells</th>
# 	<th>Specifications</th>
# </tr>
# </thead>
# <tbody>
# 	<tr>
# 		<th colspan="2" style="text-align: left;">Crystal silicon cells<br>結晶（シリコン）系太陽電池</th>
# 		<td>JISC8918, JISC8990 and IEC61215</td>
# 	</tr>
# 	<tr>
# 		<th colspan="2" style="text-align: left;">Others<br>上記以外の太陽電池</th>
# 		<td>JISC8991 and IEC61646</td>
# 	</tr>
# 	<tr>
# 		<th>　</th>
# 		<th style="text-align: left;">Amorphous cells<br>アモルファス太陽電池</th>
# 		<td>JISC8939</td>
# 	</tr>
# 	<tr>
# 		<th>　</th>
# 		<th style="text-align: left;">Multi-junction cells<br>多接合太陽電池</th>
# 		<td>JISC8943</td>
# 	</tr>
# </tbody>
# </table>

# %% [markdown]
# ## Solar Irradiance in Reference Condition / 基準状態の日射強度

# %% [markdown]
# The solar irradiance $\alpha_p$ in reference condition shall be 1.0kW/m<sup>2</sup>.

# %% [markdown]
# ## Total Design Factor of PV Array / 太陽電池アレイの総合設計係数

# %% [markdown]
# The total design factor of PV array $K_{p}$ is calculated by the equation below.

# %% [markdown]
# $$\large
# K_{p,i} = K_{HS,i} \times K_{PD,i} \times K_{PT,i} \times K_{PA,i} \times K_{PM,i} \times K_{IN}
# $$

# %% [markdown]
# Where
# $K_{HS,i}$ is the shading factor of PV array $i$. / 太陽電池アレイ$i$の日陰補正係数(表4の値)
# $K_{PD,i}$ is the efficiency deviation factor of PV array $i$. / 太陽電池アレイ$i$の経時変化補正係数(表4の値)
# $K_{PT,i}$ is the cell temperature factor of PV array $i$. / 太陽電池アレイ$i$の温度補正係数
# $K_{PA,i}$ is the array load matching factor of PV array $i$. / 太陽電池アレイ$i$のアレイ負荷整合補正係数(表4の値)
# $K_{PM,i}$ is the array circuit factor of PV array $i$. / 太陽電池アレイ$i$のアレイ回路補正係数(表4の値)
# $K_{IN}$ is the inverter circuit factor. / インバータ回路補正係数(表4の値)

# %% [markdown]
# <center>**Table 4. The value of the correction coefficient of the PV array**</center>
#
# <table>
# <thead>
# 	<tr>
# 		<th rowspan="2">Correction coefficient name</th>
# 		<th rowspan="2">Symbol</th>
# 		<th colspan="2" style="text-align: center;">Value</th>
# 	</tr>
# 	<tr>
# 		<th>Crystalline silicon type</th>
# 		<th>Other type</th>
# 	</tr>
# </thead>
# <tbody>
# 	<tr>
# 		<th>Shading factor<br>日陰補正係数</th>
# 		<th>$K_{HS}$</th>
# 		<td>1.0</td>
# 		<td>1.0</td>
# 	</tr>
# 	<tr>
# 		<th>Efficiency deviation factor<br>経時変化補正係数</th>
# 		<th>$K_{PD}$</th>
# 		<td>0.96</td>
# 		<td>0.99</td>
# 	</tr>
# 	<tr>
# 		<th>Array load matching factor<br>アレイ負荷整合補正係数</th>
# 		<th>$K_{PA}$</th>
# 		<td>0.94</td>
# 		<td>0.94</td>
# 	</tr>
# 	<tr>
# 		<th>Array circuit factor<br>アレイ回路補正係数</th>
# 		<th>$K_{PM}$</th>
# 		<td>0.97</td>
# 		<td>0.97</td>
# 	</tr>
# 	<tr>
# 		<th>Inverter circuit factor<br>インバータ回路補正係数</th>
# 		<th>$K_{IN}$</th>
# 		<td>0.90</td>
# 		<td>0.90</td>
# 	</tr>
# </tbody>
# </table>

# %% [markdown]
# The inverter circuit factor $K_{IN}$ can be calculated by the equation below regardless of Table 4.

# %% [markdown]
# $$\large
# K_{IN} = \eta_{IN,R} \times 0.97
# $$

# %% [markdown]
# Where
# $\eta_{IN,R}$ is the rated load efficiency of power conditioner. / パワーコンディショナの定格負荷効率

# %% [markdown]
# The rated load efficiency $\eta_{IN,R}$ of power conditioner shall be the rated load efficiency measured in accordance with JIS C8961:2008 "Measuring procedure of power conditioner efficiencyfor photovoltaic systems".
# If a plurality of power conditioners are installed and the rated load efficiency of all power conditioners is obvious, the value of the power conditioner with the lowest rated load efficiency among them shall be adopted. If there are one or more of the multiple power conditioners whose the rated load efficiency is unknown, use the values in Table 4 as inverter circuit factor $K_{IN}$.

# %% [markdown]
# The cell temperature factor $K_{PT,i}$ of PV array $i$ is calculated by the equation below.

# %% [markdown]
# $$\large
# K_{PT,i} = 1 + \alpha_{p,max,i} \times ( \theta_{CR,i} - 25 )
# $$

# %% [markdown]
# Where
# $\alpha_{p,max,i}$ is the maximum power temperature coefficient of PV array $i$. / 太陽電池アレイ$i$の最大出力温度係数(1/K)
# $\theta_{CR,i}$ is the weighted average PV module temperature of PV array $i$. / 太陽電池アレイ$i$の加重平均太陽電池モジュール温度(℃)

# %% [markdown]
# For the maximum power temperature coefficient $\alpha_{p,max,i}$ of PV array, the values in Table 5 shall be used.

# %% [markdown]
# <center>**Table 5. The maximum power temperature coefficient of PV array**</center>
#
# <table>
# <thead>
# <tr>
# 	<th>Crystalline silicon type</th>
# 	<th>Other type</th>
# </tr>
# </thead>
# <tbody>
# 	<tr>
# 		<td>－0.0041</td>
# 		<td>－0.0020</td>
# 	</tr>
# </tbody>
# </table>

# %% [markdown]
# The weighted average PV module temperature $\theta_{CR,i}$ of PV array $i$ is calculated by the equation below.

# %% [markdown]
# $$\large
# \theta_{CR,i} = \theta_{A} + \left(  \frac{f_{A,i}}{f_{B,i} \times (V_i)^{0.8} + 1} + 2 \right) \times I_{s,i} \times 10^{-3} - 2
# $$

# %% [markdown]
# Where
# $\theta_{A}$ is the ambient temperature. / 外気温度(℃)
# $V_{i}$ is the wind speed on the installation surface of PV array $i$. / 太陽電池アレイ$i$の設置面における風速(m/s)
# $I_{S,i}$ is the solar irradiation per unit area of installation surface of PV array $i$. / 太陽電池アレイ$i$の設置面の単位面積当たりの日射量(W/m<sup>2</sup>)
# $f_{A,i}$, $f_{B,i}$ is the coefficient obtained from Table 6 according to the installation configuration of the PV array $i$ specified in Table 7. / 太陽電池アレイ$i$における表 7 に定める設置方式に応じて表 6 より求まる係数

# %% [markdown]
# The ambient temperature $\theta_{A}$ shall use the outside air temperature in the "annual insolation amount area classification" and the value will be shown in Chapter 11 "Other" section 2 "Area classification and solar radiation amount related to solar radiation". The wind speed $V_{i}$ on the installation surface of PV array $i$ shall be equal to 1.5 regardless of region classification, date and time.

# %% [markdown]
# <center>**Table 6. The values of coefficients ݂$f_{A}$ and $f_{B}$**</center>
#
# <table>
# <thead>
# <tr>
# 	<th>Installation configuration of PV array</th>
# 	<th>$f_{A}$</th>
# 	<th>$f_{B}$</th>
# </tr>
# </thead>
# <tbody>
# 	<tr>
#         <th>Mounted type<br>架台設置形</th>
# 		<td>46</td>
# 		<td> 0.41</td>
# 	</tr>
# 	<tr>
#         <th>Roof top type<br>屋根置き形</th>
# 		<td>50</td>
# 		<td> 0.38</td>
# 	</tr>
# 	<tr>
#         <th>Other<br>その他</th>
# 		<td>57</td>
# 		<td> 0.33</td>
# 	</tr>
# </tbody>
# </table>

# %% [markdown]
# <center>**Table 7. PV array configuration options**</center>
#
# <table>
# <thead>
# <tr>
# 	<th>Installation configuration</th>
# 	<th>Conditions</th>
# </tr>
# </thead>
# <tbody>
# 	<tr>
# 		<th>Mounted type<br>架台設置形</th>
# 		<td>In the case of a PV array in which a PV module is installed indirectly with a gap from the roof,<br> and a structure other than the roof type<br>
#             太陽電池モジュールを、屋根と空隙を設けて間接に設置した太陽電池アレイで屋根置き形以外のものの場合</td>
# 	</tr>
# 	<tr>
# 		<th>Roof top type<br>屋根置き形</th>
# 		<td>In the case of a PV module installed indirectly with a gap in parallel to the roof<br>太陽電池モジュールを、屋根と平行に空隙を設けて間接に設置した場合</td>
# 	</tr>
# 	<tr>
# 		<th>Other<br>その他</th>
# 		<td>In the installation method other than the above, <br>in the case of "roof material integral type" among PV arrays for roof, a PV array for facade and for window etc.<br>
#             上記以外の設置方式で、屋根用アレイのうち「屋根材一体形」の場合、壁用アレイ及び窓用アレイ等の場合</td>
# 	</tr>
# </tbody>
# </table>
